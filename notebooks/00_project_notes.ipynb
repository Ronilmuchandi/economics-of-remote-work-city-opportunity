# %% [markdown]
# <a href="https://colab.research.google.com/github/Ronilmuchandi/economics-of-remote-work-city-opportunity/blob/main/notebooks/00_project_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Economics of Remote Work-City-Level Opportunity & Fragility (2022–2025)
#
# ## Scope
# - Global cities (50–100)
# - Timeframe: 2022–2025
# - Focus: Business + Finance
# - Goal: Opportunity Index and Fragility Index

# %% [markdown]
# ## Roadmap
# 1. Select cities
# 2. Select datasets
# 3. Clean and merge data
# 4. Build indices
# 5. Analyze and model
# 6. Scenario analysis
# 7. Dashboard and insights

# %% [markdown]
# ## Primary Dataset (Spine)
#
# Remote job demand by US city over time (2022–2025).
#
# This dataset represents the core signal of the project and captures how demand
# for remote roles is distributed and evolving across major US cities.
# All other datasets are used to explain, stress-test, or contextualize this signal.

# %% [markdown]
# ## Data Inventory
#
# | Dataset Role | Dataset Name | Source | Geography Level | Time Coverage | Key Variables |
# |-------------|--------------|--------|-----------------|---------------|---------------|
# | Spine | Remote Job Demand | Indeed Hiring Lab | US Metro / City | 2022–2025 | % remote postings, posting volume |
# | Wing 1 | Housing Cost Pressure | Zillow ZORI | US City / Metro | 2022–2025 | Rent index, YoY rent growth |
# | Wing 2 | Migration / Mobility | US Census Migration | US Metro | 2022–2025 | Inflows, outflows, net migration |
